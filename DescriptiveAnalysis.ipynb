# %%
import pandas as pd

subdf = pd.read_csv('RolexSubmarinerListings_Yearly.csv')
sampledf = pd.read_csv('2020Submariner_50s.csv')

# %%
# %matplotlib inline
subdf.boxplot('price', by='Year', figsize=(20,8))

# %%
# %matplotlib notebook
sampledf.boxplot('price', by=['Dial','Case material'])
# sampledf.boxplot('price', by='Condition')
# Out:
# <img src="data:image/png;base64,..." width="640">
