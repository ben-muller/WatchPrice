# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ScrapeData import GetWatchDetails
GetWatchDetails('test',1,'7206794.htm').T
# Out:
#                                                      7206794.htm
# 0
# Availability                                       Available now
# Basic Info                                            Basic Info
# Bezel material                                        White gold
# Bracelet color                                              Gold
# Bracelet material                                     White gold
# Bracelet/strap                                    Bracelet/strap
# Brand                                                      Rolex
# Caliber                                                  Caliber
# Case                                                        Case
# Case diameter                                              40 mm
# Case material                                         White gold
# Clasp                                                 Fold clasp
# Clasp material                                        White Gold
# Condition                Good (Light signs of wear or scratches)
# Crystal                                         Sapphire crystal
# Dial                                                       Black
# Dial numerals                                    Arabic numerals
# Expected delivery                    Jun 12, 2020 - Jun 20, 2020
# Functions                                              Functions
# Gender                                        Men's watch/Unisex
# Listing number                                            4AGSQ3
# Location                           Germany, Puchheim bei München
# Model                                                    Daytona
# Movement                                               Automatic
# Movement/Caliber                                            4130
# Number of jewels                                              44
# Payment Method                                     Bank transfer
# Power reserve                                               72 h
# Reference number                       116509 in 116576TBR optik
# Scope of delivery            No original box, no original papers
# Water resistance                                          10 ATM
# Year                                                        2009
# name                                                        test
# price                                                          1
# url                https://www.chrono24.com.au/rolex/7206794.htm

# %%
from ScrapeData import GetListings
import numpy as np
# subdf = pd.DataFrame()
for year in range(1980,2010):
    tempdf = GetListings(filters={'query':'submariner','year':year}, brand='rolex')
    tempdf['Year'] = year
    subdf = subdf.append(tempdf)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
subdf['id'] = subdf['url'].str.extract('id(.*)')[0]
subdf.head()
# Out:
#    @type               availability  \
# 0  Offer  http://schema.org/InStock
# 1  Offer  http://schema.org/InStock
# 2  Offer  http://schema.org/InStock
# 3  Offer  http://schema.org/InStock
# 4  Offer  http://schema.org/InStock
#
#                                                                                     name  \
# 0  Rolex 2019 Rolex Submariner No-Date SCRAMBLED SERIAL 114060 Steel Ceramic 40mm Watch
# 1                          Rolex Submariner 116610LN Date MK1 Chromalight Full Set 2010
# 2                                                                 Rolex Submariner Date
# 3                                                  Rolex Submariner (No Date) '4 Liner'
# 4                                   Rolex Submariner REF 16610 V- Serie, B&P Neuzustand
#
#      price  \
# 0  11908.0
# 1  17610.0
# 2  16163.0
# 3  15014.0
# 4  17848.0
#
#                                                                                                                                 url  \
# 0  https://www.chrono24.com.au/rolex/2019-rolex-submariner-no-date-scrambled-serial-114060-steel-ceramic-40mm-watch--id15303238.htm
# 1                          https://www.chrono24.com.au/rolex/submariner-116610ln-date-mk1-chromalight-full-set-2010--id15297376.htm
# 2                                                                 https://www.chrono24.com.au/rolex/submariner-date--id15295204.htm
# 3                                                      https://www.chrono24.com.au/rolex/submariner-no-date-4-liner--id15295160.htm
# 4                                     https://www.chrono24.com.au/rolex/submariner-ref-16610-v--serie-bp-neuzustand--id15294668.htm
#
#    image.@type  \
# 0  ImageObject
# 1  ImageObject
# 2  ImageObject
# 3  ImageObject
# 4  ImageObject
#
#                                                                           image.contentUrl  \
# 0  https://cdn2.chrono24.com/images/uhren/15303238-3jelcfbdfch9ausoxkez6ton-ExtraLarge.jpg
# 1  https://cdn2.chrono24.com/images/uhren/15297376-cgrlnrx3moys9gs5azfmozet-ExtraLarge.jpg
# 2  https://cdn2.chrono24.com/images/uhren/15295204-mntz8b8b3900v96vumwjdopc-ExtraLarge.jpg
# 3  https://cdn2.chrono24.com/images/uhren/15295160-qkgu58uulb9yew8s4ovx5itf-ExtraLarge.jpg
# 4  https://cdn2.chrono24.com/images/uhren/15294668-hjiyauc96h95yfrqmveuyqeb-ExtraLarge.jpg
#
#    Year            id
# 0  2010  15303238.htm
# 1  2010  15297376.htm
# 2  2010  15295204.htm
# 3  2010  15295160.htm
# 4  2010  15294668.htm

# %%
pd.set_option('display.max_colwidth', None)
sampledf = pd.DataFrame()
for index, row in subdf.loc[subdf['Year']==2020].sample(10).iterrows():
    sampledf = sampledf.append(GetWatchDetails(row['name'],row['price'],row['id']))

# %%
# %matplotlib notebook
sampledf.boxplot('price', by='Reference number')
# Out:
# <img src="data:image/png;base64,..." width="707">

# %%
# %matplotlib inline
subdf.boxplot('price', by='Year', figsize=(20,8))

# %%
outdf2 = pd.DataFrame()

for index, row in tqdm_notebook(outdf.head(1000).iterrows(), total=len(outdf.head(1000))):
#     outdf2 = pd.concat([outdf2,GetWatchDetails(row['name'], row['price'], row['link'])], axis=1, join='inner')
    outdf2 = outdf2.append(GetWatchDetails(row['name'], row['price'], row['link']), sort=False)
display(outdf2)
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# https://www.chrono24.com.au/rolex/12933249.htm
# HTTP Error 403: Forbidden
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-164-15daaccc0398> in <module>()
#       3 for index, row in tqdm_notebook(outdf.head(1000).iterrows(), total=len(outdf.head(1000))):
#       4 #     outdf2 = pd.concat([outdf2,GetWatchDetails(row['name'], row['price'], row['link'])], axis=1, join='inner')
# ----> 5     outdf2 = outdf2.append(GetWatchDetails(row['name'], row['price'], row['link']), sort=False)
#       6 display(outdf2)
#
# <ipython-input-163-4ffe3f4cc59a> in GetWatchDetails(name, price, link)
#      15
#      16 #     display(pd.concat([page[0].set_index(0).transpose(),page[1].set_index(0).transpose()], axis=1))
# ---> 17     tempdf = pd.concat([page[0].set_index(0).transpose(),page[1].set_index(0).transpose()], axis=1)
#      18     if 'Others' in tempdf.columns:
#      19         tempdf = tempdf.loc[:,:'Others']
#
# UnboundLocalError: local variable 'page' referenced before assignment

# %%
outdf2.to_csv('watches.csv')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
GetWatchDetails('test',100,'12933230.htm')
# Out:
# Index(['Condition', 'Scope of delivery', 'Availability', 'Expected delivery',
#        'Payment Method', 'Basic Info', 'Listing number', 'Reference number',
#        'Brand', 'Model', 'Movement', 'Case material', 'Bracelet material',
#        'Year', 'Condition', 'Scope of delivery', 'Gender', 'Location',
#        'Caliber', 'Movement', 'Movement/Caliber', 'Power reserve',
#        'Number of jewels', 'Case', 'Case material', 'Case diameter',
#        'Water resistance', 'Bezel material', 'Glass', 'Dial', 'Dial numerals',
#        'Bracelet/strap', 'Bracelet material', 'Bracelet color', 'Clasp',
#        'Clasp material', 'Functions', 'Date', 'Others'],
#       dtype='object', name=0)
# 0              Availability  Basic Info Bezel material Bracelet color  \
# 12933230.htm  Available now  Basic Info    Yellow gold          Brown
#
# 0            Bracelet material  Bracelet/strap  Brand  Caliber  Case  \
# 12933230.htm           Leather  Bracelet/strap  Rolex  Caliber  Case
#
# 0            Case diameter  ...  Others Payment Method Power reserve  \
# 12933230.htm         34 mm  ...  Others  Bank transfer          48 h
#
# 0            Reference number                 Scope of delivery  \
# 12933230.htm             1503  Original box, no original papers
#
# 0            Water resistance  Year  name price  \
# 12933230.htm           10 ATM  1979  test   100
#
# 0                                                        url
# 12933230.htm  https://www.chrono24.com.au/rolex/12933230.htm
#
# [1 rows x 37 columns]

# %%
proxies = {
#     "http": 'http://101.255.64.246:32663', 
    "https": 'https://45.112.56.142:51618'
}

r = requests.get('https://www.chrono24.com.au/rolex/12933234.htm', proxies=proxies)
print(r.text)
pd.read_html(r.text)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# c:\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# c:\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     594             if is_new_proxy_conn:
# --> 595                 self._prepare_proxy(conn)
#     596
#
# c:\python36\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     815
# --> 816         conn.connect()
#     817
#
# c:\python36\lib\site-packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# c:\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x0000018E704419B0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# c:\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.chrono24.com.au', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000018E704419B0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',)))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# <ipython-input-194-e5608c19c439> in <module>()
#       4 }
#       5
# ----> 6 r = requests.get('https://www.chrono24.com.au', proxies=proxies)
#       7 print(r.text)
#       8 pd.read_html(r.text)
#
# c:\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='www.chrono24.com.au', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000018E704419B0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',)))

# %%
mydict = {}
for i in range(30):
    year = 2019-i
    print(year)
    r = requests.get(f'https://www.chrono24.com.au/search/index.htm?braceletMaterial=407&caseMaterials=4&dosearch=true&gender=1401&manufacturerIds=221&maxAgeInDays=0&models=955&pageSize=120&priceFrom=0&priceTo=-1&redirectToSearchIndex=true&sortorder=11&year={year}')
#     if r.url != url:
#         print(url)
#         print('done')
    #     break
    if '<script type="application/ld+json">\n' in r.text:
        j = r.text.split('<script type="application/ld+json">\n')[1].split('\n   </script>')[0].replace('\n','').replace('\t','')
        j = json.loads(j) 
        df = json_normalize(j['@graph'][1]['offers']) 
        # outdf = outdf.append(df, sort=False)
    #     display(df['price'].median())
    #     print(str(year)+': '+str(df['price'].median()))
        mydict[year] = [df['price'].median()]
        display(df)

# display(pd.DataFrame(mydict))
# Out:
# 2019
#     @type               availability  \
# 0   Offer  http://schema.org/InStock
# 1   Offer  http://schema.org/InStock
# 2   Offer  http://schema.org/InStock
# 3   Offer  http://schema.org/InStock
# 4   Offer  http://schema.org/InStock
# 5   Offer  http://schema.org/InStock
# 6   Offer  http://schema.org/InStock
# 7   Offer  http://schema.org/InStock
# 8   Offer  http://schema.org/InStock
# 9   Offer  http://schema.org/InStock
# 10  Offer  http://schema.org/InStock
# 11  Offer  http://schema.org/InStock
# 12  Offer  http://schema.org/InStock
# 13  Offer  http://schema.org/InStock
# 14  Offer  http://schema.org/InStock
# 15  Offer  http://schema.org/InStock
# 16  Offer  http://schema.org/InStock
# 17  Offer  http://schema.org/InStock
# 18  Offer  http://schema.org/InStock
# 19  Offer  http://schema.org/InStock
# 20  Offer  http://schema.org/InStock
# 21  Offer  http://schema.org/InStock
# 22  Offer  http://schema.org/InStock
# 23  Offer  http://schema.org/InStock
# 24  Offer  http://schema.org/InStock
# 25  Offer  http://schema.org/InStock
# 26  Offer  http://schema.org/InStock
# 27  Offer  http://schema.org/InStock
# 28  Offer  http://schema.org/InStock
# 29  Offer  http://schema.org/InStock
# 30  Offer  http://schema.org/InStock
# 31  Offer  http://schema.org/InStock
# 32  Offer  http://schema.org/InStock
# 33  Offer  http://schema.org/InStock
# 34  Offer  http://schema.org/InStock
# 35  Offer  http://schema.org/InStock
# 36  Offer  http://schema.org/InStock
# 37  Offer  http://schema.org/InStock
# 38  Offer  http://schema.org/InStock
# 39  Offer  http://schema.org/InStock
#
#                                                  name  price  \
# 0   Rolex Oyster Perpetual Date 34mm Orig Dia Blat...  18191
# 1   Rolex Oyster Perpetual Date 34mm Orig Dia Blat...  18191
# 2                   Rolex Date - Limited edition /35   16196
# 3    Rolex Oyster Perpetual Date 34mm Dia Blatt 2019   13225
# 4   Rolex Oyster Perpetual Date 34mm Edelstahl/Wei...  13043
# 5                   Rolex Date - Limited edition /35   12786
# 27  https://cdn2.chrono24.com/images/uhren/images_...
# 28  https://cdn2.chrono24.com/images/uhren/images_...
# 29  https://cdn2.chrono24.com/images/uhren/images_...
# 1990
#     @type               availability  \
# 0   Offer  http://schema.org/InStock
# 1   Offer  http://schema.org/InStock
# 2   Offer  http://schema.org/InStock
# 3   Offer  http://schema.org/InStock
# 4   Offer  http://schema.org/InStock
# 5   Offer  http://schema.org/InStock
# 6   Offer  http://schema.org/InStock
# 7   Offer  http://schema.org/InStock
# 8   Offer  http://schema.org/InStock
# 9   Offer  http://schema.org/InStock
# 10  Offer  http://schema.org/InStock
# 11  Offer  http://schema.org/InStock
# 12  Offer  http://schema.org/InStock
# 13  Offer  http://schema.org/InStock
# 14  Offer  http://schema.org/InStock
# 15  Offer  http://schema.org/InStock
# 16  Offer  http://schema.org/InStock
# 17  Offer  http://schema.org/InStock
# 18  Offer  http://schema.org/InStock
# 19  Offer  http://schema.org/InStock
# 20  Offer  http://schema.org/InStock
# 21  Offer  http://schema.org/InStock
# 22  Offer  http://schema.org/InStock
# 23  Offer  http://schema.org/InStock
# 24  Offer  http://schema.org/InStock
#
#                                                  name price  \
# 0                  Rolex Oyster Perpetual Date 15200   6894
# 1                                         Rolex Date   6786
# 2   Rolex Oyster Perpetual Date Ref.15210 mit Diam...  6604
# 3                        Rolex Oyster Perpetual Date   6288
# 4                          Rolex Date   Watch  15200   6207
# 5                           Rolex Date  Watch  15200   6207
# 6                           Rolex Date  Watch  15210   6207
# 7                           Rolex Date  Watch  15200   6207
# 8                        Rolex Oyster Perpetual Date   6207
# 9                           Rolex Date  Watch  15200   6207
# 10                        Rolex Date Acier Réf 15210   6124
# 11                       Rolex Oyster Perpetual Date   5958
# 12                                  Rolex Date 15200   5793
# 13  Rolex Oyster Perpetual 34mm Date Steel Blue In...  5765
# 14                 Rolex Oyster Perpetual Date 15210   5626
# 15  Rolex Date Stahl Automatik Ruf: 15200 mit Role...  5626
# 16  Rolex Oyster Perpetual Date - ROLEX-Box - von ...  5460
# 17           Rolex Date 15200 - Unisex 1990 - ?%#TND   5428
# 18  Rolex Oyster Perpetual Date 15200 Mens Automat...  5273
# 19                       Rolex Oyster Perpetual Date   5131
# 20  Rolex Oyster Perpetual Date 15210 Men Automati...  5117
# 21         Rolex Date 34mm Stahl Automatik Herrenuhr   5114
# 22         Rolex Date 34mm Stahl Automatik Herrenuhr   5114
# 23  Rolex UNPOLISHED Rolex Date 15210 FULL SET 34m...  4812
# 24  Rolex | Oyster Date, Reference 1500, Stainless...  1553
#
#                                                   url  image.@type  \
# 0   https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 1   https://www.chrono24.com.au/rolex/date--id1274...  ImageObject
# 2   https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 3   https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 4   https://www.chrono24.com.au/rolex/date---watch...  ImageObject
# 5   https://www.chrono24.com.au/rolex/date--watch-...  ImageObject
# 6   https://www.chrono24.com.au/rolex/date--watch-...  ImageObject
# 7   https://www.chrono24.com.au/rolex/date--watch-...  ImageObject
# 8   https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 9   https://www.chrono24.com.au/rolex/date--watch-...  ImageObject
# 10  https://www.chrono24.com.au/rolex/date-acier-r...  ImageObject
# 11  https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 12  https://www.chrono24.com.au/rolex/date-15200--...  ImageObject
# 13  https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 14  https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 15  https://www.chrono24.com.au/rolex/date-stahl-a...  ImageObject
# 16  https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 17  https://www.chrono24.com.au/rolex/date-15200--...  ImageObject
# 18  https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 19  https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 20  https://www.chrono24.com.au/rolex/oyster-perpe...  ImageObject
# 21  https://www.chrono24.com.au/rolex/date-34mm-st...  ImageObject
# 22  https://www.chrono24.com.au/rolex/date-34mm-st...  ImageObject
# 23  https://www.chrono24.com.au/rolex/unpolished-r...  ImageObject
# 24  https://www.chrono24.com.au/rolex/-oyster-date...  ImageObject
#
#                                      image.contentUrl
# 0   https://cdn2.chrono24.com/images/uhren/images_...
# 1   https://cdn2.chrono24.com/images/uhren/images_...
# 2   https://cdn2.chrono24.com/images/uhren/images_...
# 3   https://cdn2.chrono24.com/images/uhren/images_...
# 4   https://cdn2.chrono24.com/images/uhren/images_...
# 5   https://cdn2.chrono24.com/images/uhren/images_...
# 6   https://cdn2.chrono24.com/images/uhren/images_...
# 7   https://cdn2.chrono24.com/images/uhren/images_...
# 8   https://cdn2.chrono24.com/images/uhren/images_...
# 9   https://cdn2.chrono24.com/images/uhren/images_...
# 10  https://cdn2.chrono24.com/images/uhren/images_...
# 11  https://cdn2.chrono24.com/images/uhren/images_...
# 12  https://cdn2.chrono24.com/images/uhren/images_...
# 13  https://cdn2.chrono24.com/images/uhren/images_...
# 14  https://cdn2.chrono24.com/images/uhren/images_...
# 15  https://cdn2.chrono24.com/images/uhren/images_...
# 16  https://cdn2.chrono24.com/images/uhren/images_...
# 17  https://cdn2.chrono24.com/images/uhren/images_...
# 18  https://cdn2.chrono24.com/images/uhren/images_...
# 19  https://cdn2.chrono24.com/images/uhren/images_...
# 20  https://cdn2.chrono24.com/images/uhren/images_...
# 21  https://cdn2.chrono24.com/images/uhren/images_...
# 22  https://cdn2.chrono24.com/images/uhren/images_...
# 23  https://cdn2.chrono24.com/images/uhren/images_...
# 24  https://cdn2.chrono24.com/images/uhren/images_...

# %%
display(pd.DataFrame.from_dict(mydict, orient='index'))
# Out:
#             0
# 2019  10510.0
# 2018   9428.0
# 2017  10099.0
# 2016   8938.0
# 2015   8607.0
# 2014   9269.0
# 2013   8110.0
# 2012   8938.0
# 2011   9103.0
# 2010   8459.0
# 2009   8037.0
# 2008   7489.5
# 2007   7453.0
# 2006   6405.0
# 2005   6124.0
# 2004   6455.0
# 2003   6041.5
# 2002   6399.0
# 2001   6309.0
# 2000   6399.0
# 1999   6248.0
# 1998   6091.0
# 1997   6330.0
# 1996   5776.0
# 1995   5535.0
# 1994   5784.5
# 1993   5869.5
# 1992   6124.0
# 1991   5999.5
# 1990   5793.0

# %%
mydict = {}
r = requests.get(f'https://www.chrono24.com.au/search/index.htm?braceletMaterial=407&caseMaterials=4&dosearch=true&gender=1401&manufacturerIds=221&maxAgeInDays=0&models=955&pageSize=120&priceFrom=0&priceTo=-1&redirectToSearchIndex=true&sortorder=11&year=2010')

j = r.text.split('<script type="application/ld+json">\n')[1].split('\n   </script>')[0].replace('\n','').replace('\t','')
j = json.loads(j) 
df = json_normalize(j['@graph'][1]['offers']) 
mydict['2010'] = [df['price'].median()]
display(pd.DataFrame.from_dict(mydict, orient='index'))
# display(pd.DataFrame(mydict))
# Out:
#            0
# 2010  8459.0
